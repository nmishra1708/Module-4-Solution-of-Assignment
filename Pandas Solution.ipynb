# %% [markdown]
# # Solution of Assignment

# %%
#imported necessary library
import pandas as pd

# %%
# read dataset 'insurance.csv' as required
data = pd.read_csv('insurance.csv')

# %%
#Show first five records of dataset
data.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# glance of last 5 records of datsets
data.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
# glance the shape of datasets how many number of rowsXcolumns are in given set
data.shape
# Out:
# (1338, 7)

# %%
# Findout simple summary statistics of dataset
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Sort the 'Insurance' dataframe in descending order of 'age'
data.sort_values(by='age', ascending=False)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 335    64    male  34.500         0     no  southwest  13822.80300
# 603    64  female  39.050         3     no  southeast  16085.12750
# 752    64    male  37.905         0     no  northwest  14210.53595
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 534    64    male  40.480         0     no  southeast  13831.11520
# ...   ...     ...     ...       ...    ...        ...          ...
# 942    18  female  40.185         0     no  northeast   2217.46915
# 46     18  female  38.665         2     no  northeast   3393.35635
# 295    18    male  22.990         0     no  northeast   1704.56810
# 50     18  female  35.625         0     no  northeast   2211.13075
# 648    18    male  28.500         0     no  northeast   1712.22700
#
# [1338 rows x 7 columns]

# %%
#Chnage the column name 'bmi' to 'Body_Mass_Index'
data.rename(columns={"bmi":"Body_Mass_Index"})
# Out:
#       age     sex  Body_Mass_Index  children smoker     region      charges
# 0      19  female           27.900         0    yes  southwest  16884.92400
# 1      18    male           33.770         1     no  southeast   1725.55230
# 2      28    male           33.000         3     no  southeast   4449.46200
# 3      33    male           22.705         0     no  northwest  21984.47061
# 4      32    male           28.880         0     no  northwest   3866.85520
# ...   ...     ...              ...       ...    ...        ...          ...
# 1333   50    male           30.970         3     no  northwest  10600.54830
# 1334   18  female           31.920         0     no  northeast   2205.98080
# 1335   18  female           36.850         0     no  southeast   1629.83350
# 1336   21  female           25.800         0     no  southwest   2007.94500
# 1337   61  female           29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Find the correlation between 'age','children' and 'charges'
df = data[['age','children', 'charges']]
corre = df.corr(method = 'pearson')
corre
# Out:
#                age  children   charges
# age       1.000000  0.042469  0.299008
# children  0.042469  1.000000  0.067998
# charges   0.299008  0.067998  1.000000

# %%
# From the entire dataset, extract all the rows from 500 to row no 1000 and extract only 'sex','children' and 'region' column.
# Store the result in 'insurance_random_set'
df = data.get(["sex","children","region"])
df = df[500:1000]
df
# Out:
#         sex  children     region
# 500    male         0  southwest
# 501    male         0  northeast
# 502    male         1  southeast
# 503    male         0  southeast
# 504  female         1  southeast
# ..      ...       ...        ...
# 995  female         3  northeast
# 996  female         3  southwest
# 997  female         0  southeast
# 998  female         3  northeast
# 999  female         0  northwest
#
# [500 rows x 3 columns]
